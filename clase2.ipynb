# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
img= cv2.imread('colores.jpg')
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

fig, axs = plt.subplots(1, 4, figsize=(20, 5))


axs[0].imshow(img_rgb)
axs[0].set_title('Imagen Original')

fig_img=axs[1].imshow(img_rgb[..., 0], cmap='gray')
fig.colorbar(fig_img, ax=axs[1], shrink=0.5)
axs[1].set_title('Canal Rojo')

fig_img=axs[2].imshow(img_rgb[..., 1], cmap='gray')
fig.colorbar(fig_img, ax=axs[2], shrink=0.5)
axs[2].set_title('Canal Verde')

fig_img=axs[3].imshow(img_rgb[..., 2], cmap='gray')
fig.colorbar(fig_img, ax=axs[3], shrink=0.5)
axs[3].set_title('Canal Azul')  

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 17
#      14 fig.colorbar(fig_img, ax=axs[1], shrink=0.5)
#      15 axs[1].set_title('Canal Rojo')
# ---> 17 fig_img=axs[2].imshow(img_rgb[..., 1], cmap='gray')
#      18 fig.colorbar(fig_img, ax=axs[2], shrink=0.5)
#      19 axs[2].set_title('Canal Verde')
#
# File c:\Users\TERABYTE10\.conda\envs\russel_pdi26\lib\site-packages\matplotlib\__init__.py:1524, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1521 @functools.wraps(func)
#    1522 def inner(ax, *args, data=None, **kwargs):
#    1523     if data is None:
# -> 1524         return func(
#    1525             ax,
#    1526             *map(cbook.sanitize_sequence, args),
#    1527             **{k: cbook.sanitize_sequence(v) for k, v in kwargs.items()})
#    1529     bound = new_sig.bind(ax, *args, **kwargs)
#    1530     auto_label = (bound.arguments.get(label_namer)
#    1531                   or bound.kwargs.get(label_namer))
#
# File c:\Users\TERABYTE10\.conda\envs\russel_pdi26\lib\site-packages\matplotlib\axes\_axes.py:5982, in Axes.imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, colorizer, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, **kwargs)
#    5979 if aspect is not None:
#    5980     self.set_aspect(aspect)
# -> 5982 im.set_data(X)
#    5983 im.set_alpha(alpha)
#    5984 if im.get_clip_path() is None:
#    5985     # image does not already have clipping set, clip to Axes patch
#
# File c:\Users\TERABYTE10\.conda\envs\russel_pdi26\lib\site-packages\matplotlib\image.py:685, in _ImageBase.set_data(self, A)
#     683 if isinstance(A, PIL.Image.Image):
#     684     A = pil_to_array(A)  # Needed e.g. to apply png palette.
# --> 685 self._A = self._normalize_image_array(A)
#     686 self._imcache = None
#     687 self.stale = True
#
# File c:\Users\TERABYTE10\.conda\envs\russel_pdi26\lib\site-packages\matplotlib\image.py:646, in _ImageBase._normalize_image_array(A)
#     640 @staticmethod
#     641 def _normalize_image_array(A):
#     642     """
#     643     Check validity of image-like input *A* and normalize it to a format suitable for
#     644     Image subclasses.
#     645     """
# --> 646     A = cbook.safe_masked_invalid(A, copy=True)
#     647     if A.dtype != np.uint8 and not np.can_cast(A.dtype, float, "same_kind"):
#     648         raise TypeError(f"Image data of dtype {A.dtype} cannot be "
#     649                         f"converted to float")
#
# File c:\Users\TERABYTE10\.conda\envs\russel_pdi26\lib\site-packages\matplotlib\cbook.py:691, in safe_masked_invalid(x, copy)
#     689     x = x.byteswap(inplace=copy).view(x.dtype.newbyteorder('N'))
#     690 try:
# --> 691     xm = np.ma.masked_where(~(np.isfinite(x)), x, copy=False)
#     692 except TypeError:
#     693     return x
#
# File c:\Users\TERABYTE10\.conda\envs\russel_pdi26\lib\site-packages\numpy\ma\core.py:1997, in masked_where(condition, a, copy)
#    1995 result = a.view(cls)
#    1996 # Assign to *.mask so that structured masks are handled correctly.
# -> 1997 result.mask = _shrink_mask(cond)
#    1998 # There is no view of a boolean so when 'a' is a MaskedArray with nomask
#    1999 # the update to the result's mask has no effect.
#    2000 if not copy and hasattr(a, '_mask') and getmask(a) is nomask:
#
# File c:\Users\TERABYTE10\.conda\envs\russel_pdi26\lib\site-packages\numpy\ma\core.py:1598, in _shrink_mask(m)
#    1594 def _shrink_mask(m):
#    1595     """
#    1596     Shrink a mask to nomask if possible
#    1597     """
# -> 1598     if m.dtype.names is None and not m.any():
#    1599         return nomask
#    1600     else:
#
# File c:\Users\TERABYTE10\.conda\envs\russel_pdi26\lib\site-packages\numpy\_core\_methods.py:64, in _any(a, axis, dtype, out, keepdims, where)
#      62 # Parsing keyword arguments is currently fairly slow, so avoid it for now
#      63 if where is True:
# ---> 64     return umr_any(a, axis, dtype, out, keepdims)
#      65 return umr_any(a, axis, dtype, out, keepdims, where=where)
#
# KeyboardInterrupt:

# %% [markdown]
# otro metodo de llamar

# %%
img_rgb[:3,:3,:]

# %% [markdown]
# muestra de pixeles para recortar una imagen

# %%
plt.imshow(img_rgb[:10,:10,:])

# %% [markdown]
# guardar la imagen

# %%
cv2.imwrite('imagen.jpg', img_rgb) #GUARDAR IMAGEN CON OPENCV
plt.imsave('imagen_nueva2.jpg', cv2.cvtColor(img_rgb, cv2.COLOR_BGR2RGB)) #GUARDAR IMAGEN CON MATPLOTLIB, SE DEBE CONVERTIR A RGB PARA QUE LOS COLORES SEAN CORRECTOS

# %% [markdown]
# EJERCICIOS PARA GENERAR UNA IMAGEN

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
plt.rcParams['figure.figsize'] = [10, 5]
size_imagen=100
R=np.ones((size_imagen,size_imagen))*225
G=np.ones((size_imagen, size_imagen))*128
B=np.ones((size_imagen, size_imagen))*0

imagen=np.dstack((R,G,B))
imagen=np.array(imagen,dtype=int)

plt.figure()
plt.imshow(imagen)
plt.title('imagen de color: naranja')
plt.show()

# %% [markdown]
# escala de grises y colores

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
img = cv2.imread('colores.jpg', cv2.IMREAD_GRAYSCALE)
#VALORES INICIALES DE PROFUNDIDAD DE COLOR
original=img.dtype
#transformando img a 16 bits
img16bits= np.uint16(img)
img_new=img16bits.dtype
print(f'Profundidad de color original: {original}')
print(f'Profundidad de color nueva: {img_new}')

plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.imshow(img, cmap='gray')
plt.title('Imagen Original')

plt.subplot(1,2,2)
plt.imshow(img, cmap='gray')
plt.title('Imagen con 16 bits')

#guardado con cv2 y matplotlib

cv2.imwrite('imagen_16bits.jpg', img16bits) #GUARDAR IMAGEN CON OPENCV
plt.imsave('imagen_nueva_16bits.jpg', img16bits, cmap='gray')
