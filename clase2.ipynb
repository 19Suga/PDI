# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
img= cv2.imread('colores.jpg')
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

fig, axs = plt.subplots(1, 4, figsize=(20, 5))


axs[0].imshow(img_rgb)
axs[0].set_title('Imagen Original')

fig_img=axs[1].imshow(img_rgb[..., 0], cmap='gray')
fig.colorbar(fig_img, ax=axs[1], shrink=0.5)
axs[1].set_title('Canal Rojo')

fig_img=axs[2].imshow(img_rgb[..., 1], cmap='gray')
fig.colorbar(fig_img, ax=axs[2], shrink=0.5)
axs[2].set_title('Canal Verde')

fig_img=axs[3].imshow(img_rgb[..., 2], cmap='gray')
fig.colorbar(fig_img, ax=axs[3], shrink=0.5)
axs[3].set_title('Canal Azul')  

plt.tight_layout()
plt.show()

# %% [markdown]
# muestra matrices

# %%
img_rgb[:3,:3,:]

# %% [markdown]
# muestra de pixeles para recortar una imagen

# %%
plt.imshow(img_rgb[:10,:10,:])

# %% [markdown]
# guardar la imagen

# %%
cv2.imwrite('imagen.jpg', img_rgb) #GUARDAR IMAGEN CON OPENCV
plt.imsave('imagen_nueva3.jpg', cv2.cvtColor(img_rgb, cv2.COLOR_BGR2RGB)) #GUARDAR IMAGEN CON MATPLOTLIB, SE DEBE CONVERTIR A RGB PARA QUE LOS COLORES SEAN CORRECTOS

# %% [markdown]
# EJERCICIOS PARA GENERAR UNA IMAGEN

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
plt.rcParams['figure.figsize'] = [10, 5]
size_imagen=100
R=np.ones((size_imagen,size_imagen))*225
G=np.ones((size_imagen, size_imagen))*128
B=np.ones((size_imagen, size_imagen))*0

imagen=np.dstack((R,G,B))
imagen=np.array(imagen,dtype=int)

plt.figure()
plt.imshow(imagen)
plt.title('imagen de color: naranja')
plt.show()

# %% [markdown]
# escala de grises y colores

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
img = cv2.imread('colores.jpg', cv2.IMREAD_GRAYSCALE)
#VALORES INICIALES DE PROFUNDIDAD DE COLOR
original=img.dtype
#transformando img a 16 bits
img16bits= np.uint16(img)
img_new=img16bits.dtype
print(f'Profundidad de color original: {original}')
print(f'Profundidad de color nueva: {img_new}')

plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.imshow(img, cmap='gray')
plt.title('Imagen Original')

plt.subplot(1,2,2)
plt.imshow(img, cmap='gray')
plt.title('Imagen con 16 bits')

#guardado con cv2 y matplotlib
cv2.imwrite('imagen_16bits.jpg', img16bits) #GUARDAR IMAGEN CON OPENCV
plt.imsave('imagen_nueva_16bits1.jpg', img16bits, cmap='gray')
# Out:
# Profundidad de color original: uint8
# Profundidad de color nueva: uint16

# %% [markdown]
# Practica cuadrante

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# Crear imagen negra de 100x100
img = np.zeros((100, 100, 3), dtype=np.uint8)

colores = [
    (0, 255, 255),  # Amarillo
    (255, 0, 0),    # Azul
    (0, 0, 255),    # Rojo
    (0, 255, 0)     # Verde
]

# Coordenadas de los cuadrantes
posiciones = [
    (0, 50, 0, 50),     # Sup izquierdo
    (0, 50, 50, 100),   # Sup derecho
    (50, 100, 0, 50),   # Inf izquierdo
    (50, 100, 50, 100)  # Inf derecho
]

for i in range(4):
    y1, y2, x1, x2 = posiciones[i]
    img[y1:y2, x1:x2] = np.ones((50, 50, 3), dtype=np.uint8) * colores[i]

# Convertir a RGB para mostrar con matplotlib
imgRGB = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(imgRGB)
plt.axis('off')
plt.show()

# %% [markdown]
# cubo 3x3

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# Crear imagen negra de 100x100
img = np.zeros((100, 100, 3), dtype=np.uint8)

colores = [
    (0, 255, 255),  # Amarillo
    (255, 0, 0),    # Azul
    (0, 0, 255),    # Rojo
    (0, 255, 0)     # Verde
]
